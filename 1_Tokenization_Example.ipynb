# %%
corpus = """Hello welcome, to chetan bhagat's NLP first lecture. 
please do like my repository if you are watching this! to become expert in NLP.
"""

# %%
print(corpus)
# Out:
# Hello welcome, to chetan bhagat's NLP first lecture.
# please do like my repository if you are watching this! to become expert in NLP.

# %%
import nltk 
nltk.download('punkt')
## tokenization 
## sentence --> paragraphs 
from nltk.tokenize import sent_tokenize
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Chetan
# [nltk_data]     Bhagat\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
documents=sent_tokenize(corpus)

# %%
documents
# Out:
# ["Hello welcome, to chetan bhagat's NLP first lecture.",
#  'please do like my repository if you are watching this!',
#  'to become expert in NLP.']

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello welcome, to chetan bhagat's NLP first lecture.
# please do like my repository if you are watching this!
# to become expert in NLP.

# %%
## tokenization 
## paragraph into words 
## sentence into words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'to',
#  'chetan',
#  'bhagat',
#  "'s",
#  'NLP',
#  'first',
#  'lecture',
#  '.',
#  'please',
#  'do',
#  'like',
#  'my',
#  'repository',
#  'if',
#  'you',
#  'are',
#  'watching',
#  'this',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'welcome', ',', 'to', 'chetan', 'bhagat', "'s", 'NLP', 'first', 'lecture', '.']
# ['please', 'do', 'like', 'my', 'repository', 'if', 'you', 'are', 'watching', 'this', '!']
# ['to', 'become', 'expert', 'in', 'NLP', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'to',
#  'chetan',
#  'bhagat',
#  "'",
#  's',
#  'NLP',
#  'first',
#  'lecture',
#  '.',
#  'please',
#  'do',
#  'like',
#  'my',
#  'repository',
#  'if',
#  'you',
#  'are',
#  'watching',
#  'this',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'to',
#  'chetan',
#  'bhagat',
#  "'s",
#  'NLP',
#  'first',
#  'lecture.',
#  'please',
#  'do',
#  'like',
#  'my',
#  'repository',
#  'if',
#  'you',
#  'are',
#  'watching',
#  'this',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']
