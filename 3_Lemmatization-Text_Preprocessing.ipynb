# %% [markdown]
# ## Wordnet Lemmatizer
# Lemmatization technique is like stemming. The output we will get after lemmatization is called 'lemma', which is a root word rather than root stem, the output of stemming. after lemmatization, we will be getting a valid word that means the same thing.
#
#
# NLTK provides WordNetLemmatizer class which is a thin wrapper around the wordnet corpus. this class morphy() function to the WordNetCorpusReader class to find a lemma. let's understand with an example

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\Chetan
# [nltk_data]     Bhagat\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package omw-1.4 to C:\Users\Chetan
# [nltk_data]     Bhagat\AppData\Roaming\nltk_data...

# %%
lemmatizer=WordNetLemmatizer()

# %%
'''
POS
Noun-n
verb-v
adjective-a
adverb-r
'''
lemmatizer.lemmatize("going",pos="v")
# Out:
# 'go'

# %%
words=["eating","eats","eaten","writing","writes","programming","programs","history","finally","finalize"]

# %%
for word in words:
    print(word+"--->"+lemmatizer.lemmatize(word,pos='v'))
# Out:
# eating--->eat
# eats--->eat
# eaten--->eat
# writing--->write
# writes--->write
# programming--->program
# programs--->program
# history--->history
# finally--->finally
# finalize--->finalize

# %%
lemmatizer.lemmatize("fairly",pos='v'),lemmatizer.lemmatize("sportingly")
# Out:
# ('fairly', 'sportingly')
