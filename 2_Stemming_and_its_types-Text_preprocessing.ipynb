# %% [markdown]
# ## Stemming
# stemming is the process of reducing a word to its word stem that affixes to suffixes and prefixes or to the roots of words known as lemma. stemming is important in natural language understanding(NLU) and natural language processing(NLP)

# %%
words=["eating","eats","eaten","writing","writes","programming","programs","history","finally","finalize"]

# %% [markdown]
# ## PorterStemmer

# %%
from nltk.stem import PorterStemmer

# %%
stemming=PorterStemmer()

# %%
for word in words:
    print(word+"---->"+stemming.stem(word))
# Out:
# eating---->eat
# eats---->eat
# eaten---->eaten
# writing---->write
# writes---->write
# programming---->program
# programs---->program
# history---->histori
# finally---->final
# finalize---->final

# %%
stemming.stem("congratulations")
# Out:
# 'congratul'

# %%
stemming.stem("sitting")
# Out:
# 'sit'

# %% [markdown]
# ## RegexpStemmer class
# NLTK has regexpstemmer class with the help of which we can easily implement regular expression stemmer algorithms. it basically takes a single regular expression and remove any prefix or suffix that matches the expression.let's see an example

# %%
from nltk.stem import RegexpStemmer

# %%
reg_stemmer=RegexpStemmer('ing$|s$|e$|able$', min=5)

# %%
reg_stemmer.stem("eating")
# Out:
# 'eat'

# %%
reg_stemmer.stem("iaaeating")
# Out:
# 'iaaeat'

# %%
reg_stemmer.stem("unable")
# Out:
# 'un'

# %% [markdown]
# ## Snowball Stemmer
# Snowball Stemmer is a stemming algorithm in Natural Language Processing (NLP) that reduces a word to its root (stem) by removing prefixes or suffixes. It is more accurate and flexible than the Porter Stemmer.

# %%
from nltk.stem import SnowballStemmer

# %%
snowballstemmer=SnowballStemmer("english")

# %%
for word in words:
    print(word+"--->"+snowballstemmer.stem(word))
# Out:
# eating--->eat
# eats--->eat
# eaten--->eaten
# writing--->write
# writes--->write
# programming--->program
# programs--->program
# history--->histori
# finally--->final
# finalize--->final

# %%
## porterstemmer
stemming.stem("fairly"),stemming.stem("sportingly")
# Out:
# ('fairli', 'sportingli')

# %%
## snowballstemmer
snowballstemmer.stem("fairly"),snowballstemmer.stem("sportingly")
# Out:
# ('fair', 'sport')

# %%
snowballstemmer.stem("goes")
# Out:
# 'goe'
