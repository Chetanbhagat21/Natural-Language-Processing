# %% [markdown]
# ## Named Entitiy Recognition

# %% [raw]
# sentence="the eiffel tower was built from 1887 to 1889 by french engineer gustave eiffel, whose company specialized in building metal frameworks and structures."
# """
# Person Eg: Chetan D Bhagat
# Place Or Location Eg: India
# Date Eg: July,20-07-2026
# Time Eg: 4:30pm
# Money Eg: 1 million dollar
# Organization Eg: Bhagat Limited
# Percentage Eg: 80, twenty percent
# """

# %%
sentence="the eiffel tower was built from 1887 to 1889 by french engineer gustave eiffel, whose company specialized in building metal frameworks and structures."

# %%
import nltk
words=nltk.word_tokenize(sentence)

# %%
tag_elements=nltk.pos_tag(words)

# %%
nltk.download('maxent_ne_chunker')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to C:\Users\Chetan
# [nltk_data]     Bhagat\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# True

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to C:\Users\Chetan
# [nltk_data]     Bhagat\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
nltk.ne_chunk(tag_elements).draw()
