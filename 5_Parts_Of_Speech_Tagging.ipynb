# %% [markdown]
# ## Parts Of Speech Tags

# %% [raw]
# TAG   DESCRIPTION                                 EXAMPLE
# ----  ------------------------------------------  -----------------------
#
# CC    ---> Coordinating conjunction               ---> and
# CD    ---> Cardinal number                        ---> 1, one
# DT    ---> Determiner                             ---> the
# EX    ---> Existential there                      ---> there is
# FW    ---> Foreign word                           ---> les
# IN    ---> Preposition or subordinating conjunction ---> in, of, like
# JJ    ---> Adjective                              ---> green, poor
# JJR   ---> Adjective, comparative                 ---> greener
# JJS   ---> Adjective, superlative                 ---> greenest
# LS    ---> List item marker                       ---> 1)
# MD    ---> Modal                                  ---> could, will
# NN    ---> Noun, singular or mass                 ---> table
# NNS   ---> Noun, plural                           ---> tables
# NNP   ---> Proper noun, singular                  ---> John
# NNPS  ---> Proper noun, plural                    ---> Vikings
# PDT   ---> Predeterminer                          ---> both the boys
# POS   ---> Possessive ending                      ---> friend's
# PRP   ---> Personal pronoun                       ---> I, he, it
# PRP$  ---> Possessive pronoun                     ---> my, his
# RB    ---> Adverb                                 ---> however, usually
# RBR   ---> Adverb, comparative                    ---> better
# RBS   ---> Adverb, superlative                    ---> best
# RP    ---> Particle                               ---> give up
# SYM   ---> Symbol                                 ---> / [ = *
# TO    ---> to                                     ---> to go
# UH    ---> Interjection                           ---> Ha-Ha!, Hurrah!
# VB    ---> Verb, base form                        ---> be
# VBD   ---> Verb, past tense                       ---> was, were
# VBG   ---> Verb, gerund or present participle     ---> being
# VBN   ---> Verb, past participle                  ---> been
# VBP   ---> Verb, non-3rd person singular present  ---> am, are
# VBZ   ---> Verb, 3rd person singular present      ---> is
# WDT   ---> Wh-determiner                          ---> which
# WP    ---> Wh-pronoun                             ---> who, what
# WP$   ---> Possessive Wh-pronoun                  ---> whose
# WRB   ---> Wh-adverb                              ---> where, when

# %%
paragraph='''I stand before you not to ask for your sympathy, but to awaken your strength. A society cannot become great by keeping a section of its people in chains. A nation rises only when every citizen is treated with dignity, justice, and equality.
For centuries, many among us have been told that we are less worthy because of our birth. I reject this idea completely. A person's value is determined not by caste, but by character, knowledge, and hard work. No child enters this world with superiority or inferiority written upon them. These are divisions created by society, and what society creates, society can also change.
Remember this: freedom without equality is incomplete, and equality without education is impossible. Education is not merely a path to employment; it is the path to self-respect. A mind that is educated cannot be enslaved for long. Therefore, educate yourselves—not only to earn a livelihood, but to understand your rights and responsibilities.
I ask you not to depend on others for your progress. Stand on your own feet. Build your confidence. Organize yourselves peacefully and lawfully. Demand justice, but do so with reason, discipline, and courage. Social change achieved through knowledge is stronger and more lasting than change achieved through hatred.
Never believe that your destiny has already been decided. The future belongs to those who are willing to question injustice, challenge ignorance, and work tirelessly for a better society. Democracy is not just about casting a vote. Democracy lives when we respect one another, when the law protects every citizen equally, and when no person is denied opportunities because of birth.
I also say to those who enjoy privilege: equality does not weaken a nation—it strengthens it. Justice for one community is justice for the whole nation. The progress of India depends not on the success of a few, but on the dignity of all.
Young people, the future of this nation rests in your hands. Read more than you argue. Think more than you follow. Build more than you criticize. Let your knowledge become your greatest weapon and your character your greatest strength.
Let us build an India where no one is judged by caste, where every child has access to education, where women and men enjoy equal rights, where the Constitution is respected, and where liberty, equality, and fraternity are not merely words, but the foundation of our daily lives.
Let us move forward together with wisdom instead of prejudice, with courage instead of fear, and with unity instead of division.'''

# %%
from nltk.corpus import stopwords
sentences=nltk.sent_tokenize(paragraph)

# %%
sentences
# Out:
# ['I stand before you not to ask for your sympathy, but to awaken your strength.',
#  'A society cannot become great by keeping a section of its people in chains.',
#  'A nation rises only when every citizen is treated with dignity, justice, and equality.',
#  'For centuries, many among us have been told that we are less worthy because of our birth.',
#  'I reject this idea completely.',
#  "A person's value is determined not by caste, but by character, knowledge, and hard work.",
#  'No child enters this world with superiority or inferiority written upon them.',
#  'These are divisions created by society, and what society creates, society can also change.',
#  'Remember this: freedom without equality is incomplete, and equality without education is impossible.',
#  'Education is not merely a path to employment; it is the path to self-respect.',
#  'A mind that is educated cannot be enslaved for long.',
#  'Therefore, educate yourselves—not only to earn a livelihood, but to understand your rights and responsibilities.',
#  'I ask you not to depend on others for your progress.',
#  'Stand on your own feet.',
#  'Build your confidence.',
#  'Organize yourselves peacefully and lawfully.',
#  'Demand justice, but do so with reason, discipline, and courage.',
#  'Social change achieved through knowledge is stronger and more lasting than change achieved through hatred.',
#  'Never believe that your destiny has already been decided.',
#  'The future belongs to those who are willing to question injustice, challenge ignorance, and work tirelessly for a better society.',
#  'Democracy is not just about casting a vote.',
#  'Democracy lives when we respect one another, when the law protects every citizen equally, and when no person is denied opportunities because of birth.',
#  'I also say to those who enjoy privilege: equality does not weaken a nation—it strengthens it.',
#  'Justice for one community is justice for the whole nation.',
#  'The progress of India depends not on the success of a few, but on the dignity of all.',
#  'Young people, the future of this nation rests in your hands.',
#  'Read more than you argue.',
#  'Think more than you follow.',
#  'Build more than you criticize.',
#  'Let your knowledge become your greatest weapon and your character your greatest strength.',
#  'Let us build an India where no one is judged by caste, where every child has access to education, where women and men enjoy equal rights, where the Constitution is respected, and where liberty, equality, and fraternity are not merely words, but the foundation of our daily lives.',
#  'Let us move forward together with wisdom instead of prejudice, with courage instead of fear, and with unity instead of division.']

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Chetan Bhagat\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
## we will find out the pos tag

for i in range(len(sentences)):
    words=nltk.word_tokenize(sentences[i])
    words=[word for word in words if word not in set(stopwords.words('english'))]
    pos_tag=nltk.pos_tag(words)
    print(pos_tag)
    #sentences[i]=' '.join(words)# converting all the words into sentences
# Out:
# [('I', 'PRP'), ('stand', 'VBP'), ('ask', 'JJ'), ('sympathy', 'NN'), (',', ','), ('awaken', 'JJ'), ('strength', 'NN'), ('.', '.')]
# [('A', 'DT'), ('society', 'NN'), ('become', 'VBN'), ('great', 'JJ'), ('keeping', 'VBG'), ('section', 'NN'), ('people', 'NNS'), ('chains', 'NNS'), ('.', '.')]
# [('A', 'DT'), ('nation', 'NN'), ('rises', 'VBZ'), ('every', 'DT'), ('citizen', 'NN'), ('treated', 'VBN'), ('dignity', 'NN'), (',', ','), ('justice', 'NN'), (',', ','), ('equality', 'NN'), ('.', '.')]
# [('For', 'IN'), ('centuries', 'NNS'), (',', ','), ('many', 'JJ'), ('among', 'IN'), ('us', 'PRP'), ('told', 'VBD'), ('less', 'RBR'), ('worthy', 'JJ'), ('birth', 'NN'), ('.', '.')]
# [('I', 'PRP'), ('reject', 'VBP'), ('idea', 'NN'), ('completely', 'RB'), ('.', '.')]
# [('A', 'DT'), ('person', 'NN'), ("'s", 'POS'), ('value', 'NN'), ('determined', 'VBD'), ('caste', 'NN'), (',', ','), ('character', 'NN'), (',', ','), ('knowledge', 'NN'), (',', ','), ('hard', 'JJ'), ('work', 'NN'), ('.', '.')]
# [('No', 'DT'), ('child', 'NN'), ('enters', 'VBZ'), ('world', 'NN'), ('superiority', 'NN'), ('inferiority', 'NN'), ('written', 'VBN'), ('upon', 'IN'), ('.', '.')]
# [('These', 'DT'), ('divisions', 'NNS'), ('created', 'VBD'), ('society', 'NN'), (',', ','), ('society', 'NN'), ('creates', 'NNS'), (',', ','), ('society', 'NN'), ('also', 'RB'), ('change', 'NN'), ('.', '.')]
# [('Remember', 'NNP'), (':', ':'), ('freedom', 'NN'), ('without', 'IN'), ('equality', 'NN'), ('incomplete', 'NN'), (',', ','), ('equality', 'NN'), ('without', 'IN'), ('education', 'NN'), ('impossible', 'JJ'), ('.', '.')]
# [('Education', 'NN'), ('merely', 'RB'), ('path', 'JJ'), ('employment', 'NN'), (';', ':'), ('path', 'CC'), ('self-respect', 'NN'), ('.', '.')]
# [('A', 'DT'), ('mind', 'NN'), ('educated', 'VBD'), ('enslaved', 'VBN'), ('long', 'RB'), ('.', '.')]
# [('Therefore', 'RB'), (',', ','), ('educate', 'VB'), ('yourselves—not', 'NN'), ('earn', 'RB'), ('livelihood', 'NN'), (',', ','), ('understand', 'VB'), ('rights', 'NNS'), ('responsibilities', 'NNS'), ('.', '.')]
# [('I', 'PRP'), ('ask', 'VBP'), ('depend', 'JJ'), ('others', 'NNS'), ('progress', 'NN'), ('.', '.')]
# [('Stand', 'NNP'), ('feet', 'NNS'), ('.', '.')]
# [('Build', 'NNP'), ('confidence', 'NN'), ('.', '.')]
# [('Organize', 'NNP'), ('peacefully', 'RB'), ('lawfully', 'RB'), ('.', '.')]
# [('Demand', 'NNP'), ('justice', 'NN'), (',', ','), ('reason', 'NN'), (',', ','), ('discipline', 'NN'), (',', ','), ('courage', 'NN'), ('.', '.')]
# [('Social', 'NNP'), ('change', 'NN'), ('achieved', 'VBD'), ('knowledge', 'NN'), ('stronger', 'NN'), ('lasting', 'VBG'), ('change', 'NN'), ('achieved', 'VBN'), ('hatred', 'VBD'), ('.', '.')]
# [('Never', 'RB'), ('believe', 'VB'), ('destiny', 'NN'), ('already', 'RB'), ('decided', 'VBD'), ('.', '.')]
# [('The', 'DT'), ('future', 'JJ'), ('belongs', 'NNS'), ('willing', 'JJ'), ('question', 'NN'), ('injustice', 'NN'), (',', ','), ('challenge', 'NN'), ('ignorance', 'NN'), (',', ','), ('work', 'NN'), ('tirelessly', 'RB'), ('better', 'RB'), ('society', 'NN'), ('.', '.')]
# [('Democracy', 'NN'), ('casting', 'VBG'), ('vote', 'NN'), ('.', '.')]
# [('Democracy', 'NN'), ('lives', 'VBZ'), ('respect', 'VBP'), ('one', 'CD'), ('another', 'DT'), (',', ','), ('law', 'NN'), ('protects', 'NNS'), ('every', 'DT'), ('citizen', 'NN'), ('equally', 'RB'), (',', ','), ('person', 'NN'), ('denied', 'VBD'), ('opportunities', 'NNS'), ('birth', 'NN'), ('.', '.')]
# [('I', 'PRP'), ('also', 'RB'), ('say', 'VBP'), ('enjoy', 'JJ'), ('privilege', 'NN'), (':', ':'), ('equality', 'NN'), ('weaken', 'VBP'), ('nation—it', 'JJ'), ('strengthens', 'NNS'), ('.', '.')]
# [('Justice', 'NNP'), ('one', 'CD'), ('community', 'NN'), ('justice', 'NN'), ('whole', 'JJ'), ('nation', 'NN'), ('.', '.')]
# [('The', 'DT'), ('progress', 'NN'), ('India', 'NNP'), ('depends', 'VBZ'), ('success', 'NN'), (',', ','), ('dignity', 'NN'), ('.', '.')]
# [('Young', 'NN'), ('people', 'NNS'), (',', ','), ('future', 'JJ'), ('nation', 'NN'), ('rests', 'VBZ'), ('hands', 'NNS'), ('.', '.')]
# [('Read', 'NNP'), ('argue', 'NN'), ('.', '.')]
# [('Think', 'NNP'), ('follow', 'VBP'), ('.', '.')]
# [('Build', 'NNP'), ('criticize', 'NN'), ('.', '.')]
# [('Let', 'VB'), ('knowledge', 'VB'), ('become', 'VB'), ('greatest', 'JJS'), ('weapon', 'JJ'), ('character', 'NN'), ('greatest', 'JJS'), ('strength', 'NN'), ('.', '.')]
# [('Let', 'VB'), ('us', 'PRP'), ('build', 'VB'), ('India', 'NNP'), ('one', 'CD'), ('judged', 'VBD'), ('caste', 'NN'), (',', ','), ('every', 'DT'), ('child', 'NN'), ('access', 'NN'), ('education', 'NN'), (',', ','), ('women', 'NNS'), ('men', 'NNS'), ('enjoy', 'VBP'), ('equal', 'JJ'), ('rights', 'NNS'), (',', ','), ('Constitution', 'NNP'), ('respected', 'VBD'), (',', ','), ('liberty', 'NN'), (',', ','), ('equality', 'NN'), (',', ','), ('fraternity', 'NN'), ('merely', 'RB'), ('words', 'NNS'), (',', ','), ('foundation', 'NN'), ('daily', 'JJ'), ('lives', 'NNS'), ('.', '.')]
# [('Let', 'VB'), ('us', 'PRP'), ('move', 'VB'), ('forward', 'RB'), ('together', 'RB'), ('wisdom', 'NN'), ('instead', 'RB'), ('prejudice', 'NN'), (',', ','), ('courage', 'NN'), ('instead', 'RB'), ('fear', 'NN'), (',', ','), ('unity', 'NN'), ('instead', 'RB'), ('division', 'NN'), ('.', '.')]

# %%
print(nltk.pos_tag("taj mahal is a beautiful monument
